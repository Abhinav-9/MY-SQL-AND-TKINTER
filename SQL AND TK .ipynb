# %%
import tkinter as tk
import mysql.connector 
from tkinter import *
  
def submitact():
     
    user = Username.get()
    passw = password.get()
    data= database.get()

    logintodb(user, passw, data)
  
 
def logintodb(user, passw, data):
     
    # If paswword is enetered by the 
    # user
    if passw:
        db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                     password = passw,
                                     db =data)
        cursor = db.cursor()
         
    # If no password is enetered by the
    # user
    else:
        db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                     data =data)
        cursor = db.cursor()
def databases():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("SHOW DATABASES")
    i=1
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='databases',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
        i=i+1
    db.close()
def select_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("select first_name, last_name from actor;")
    i=1
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='first_name',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='last_name',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
        i=i+1
    db.close()
def cond_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("select upper(concat(first_name, ' ', last_name))   'Actor Name'from actor;")
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='Actor Name',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
        i=i+1
def leftjoin_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("select stf.first_name, stf.last_name, adr.address, adr.district, adr.postal_code, adr.city_id from staff stf left join address adr on stf.address_id = adr.address_id;")
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='first_name',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='last_name',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='address',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='district',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='postal_code',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='city_id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=5)
        i=i+1
def group_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("select flm.title, count(*) number_in_inventory from film flm inner join inventory inv on flm.film_id = inv.film_id where lower(flm.title) = lower('Hunchback Impossible') group by flm.title;")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='title',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='number_in_inventory',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
        i=i+1        
def input_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute(savequery1.get())
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])    
        i=i+1  
def cond1_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("select title from film where (title like 'K%' or title like 'Q%') and language_id in (select language_id from language where name = 'English') order by title;")
    i=1 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='title',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
        i=i+1 

root = tk.Tk()
root.geometry("1100x700")
root.configure(bg='red')
root.title("DBMS Login Page") 

# Definging the first row
welcome = tk.Label(root, text ="Welcome to Abhinav Database ", fg = "yellow", bg = "red",font = "Helvetica 24 bold italic")
welcome.place(x = 350, y = 20)

lblfrstrow = tk.Label(root, text ="Username:", bg='red',font = "Helvetica 12 bold italic")
lblfrstrow.place(x = 50, y = 50)
 
Username = tk.Entry(root, width = 35)
Username.place(x = 150, y = 50, width = 100)
  
lblsecrow = tk.Label(root, text ="Password:", bg='red',font = "Helvetica 12 bold italic")
lblsecrow.place(x = 50, y = 80)
 
password = tk.Entry(root, width = 35)
password.place(x = 150, y = 80, width = 100)

lblthrdrow = tk.Label(root, text ="Database:", bg='red', font = "Helvetica 12 bold italic")
lblthrdrow.place(x = 50, y = 110)
 
database = tk.Entry(root, width = 35)
database.place(x = 150, y = 110, width = 100)
 
submitbtn = tk.Button(root, text ="Login", font = "Helvetica 12 bold italic",
                      bg ='white', command = submitact)
submitbtn.place(x = 100, y = 150, width = 155)

welcome1 = tk.Label(root, text ="Pre-defined queries:", fg = "yellow", bg = "red",font = "Helvetica 16 bold italic")
welcome1.place(x = 50, y = 200)

base = tk.Button(root, text ="databases", font = "Helvetica 12 bold italic",
                      bg ='white', command = databases)
base.place(x = 150, y = 250, width = 155)
save = tk.Button(root, text ="", font = "Helvetica 12 bold italic",
                      bg ='white', command = select_query)
select = tk.Button(root, text ="first name and last name of actor", font = "Helvetica 12 bold italic",
                      bg ='white', command = select_query)
select.place(x = 350, y = 250, width = 455)
cond1 = tk.Button(root, text ="Actor Name", font = "Helvetica 12 bold italic",
                      bg ='white', command = cond_query)
cond1.place(x = 150, y = 300, width = 455)
leftjoin = tk.Button(root, text ="left join address", font = "Helvetica 12 bold italic",
                      bg ='white', command = leftjoin_query)
leftjoin.place(x = 550, y = 300, width = 455)
group= tk.Button(root, text ="No of copies of  Hunchback Impossible ", font = "Helvetica 12 bold italic",
                      bg ='white', command = group_query)
group.place(x = 150, y = 350, width = 455 )
cond1= tk.Button(root, text ="movies starting with the letters K and Q", font = "Helvetica 12 bold italic",
                      bg ='white', command = cond1_query)
cond1.place(x = 550, y = 350, width = 455)
welcome1 = tk.Label(root, text ="Queries based on user requirement :", fg = "yellow", bg = "red",font = "Helvetica 16 bold italic")
welcome1.place(x = 50, y = 400)

query = tk.Label(root, text ="enter the query:", bg='red',font = "Helvetica 14 bold italic"  )
query.place(x = 150, y = 450) 
savequery1 = tk.Entry(root, width = 35)
savequery1.place(x = 304, y = 455, width = 700)
inputs= tk.Button(root, text ="input ", font = "Helvetica 12 bold italic",
                      bg ='white', command = input_query)
inputs.place(x = 304, y = 500, width = 455)
root.mainloop()
